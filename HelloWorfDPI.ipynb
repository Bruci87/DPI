# %%
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('moon.png', cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Hello World')
plt.axis('off')
plt.show()
